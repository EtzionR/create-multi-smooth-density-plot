# %% [markdown]
# <h1><left>multi-smooth-density-plot - implementation</left></h1>
#
# <h4><left>created by Etzion Harari - etzionhar@gmail.com</left></h4>

# %% [markdown]
# <h2><left>Introduction</left></h2>
#
# <h4><left>importing</left></h4>

# %%
from pandas import read_excel
from multi_density import create_multi_density

# %% [markdown]
# <h4><left>example 1: ten fields</left></h4>

# %%
data = read_excel('example1.xlsx')
create_multi_density(data,list(data.columns),"density_1")

# %% [markdown]
# <h4><left>example 2: only one field</left></h4>

# %%
data = read_excel('example2.xlsx')
create_multi_density(data,'one',"density_2")

# %% [markdown]
# <h4><left>example 3: two fields</left></h4>

# %%
data = read_excel('example3.xlsx')
create_multi_density(data,['field_1','field_2'],"density_3")

# %% [markdown]
# <h4><left>example 4: Specific fields</left></h4>

# %%
data = read_excel('example4.xlsx')
create_multi_density(data,['a','b','c','d','e'],"density_4")

# %% [markdown]
# .
# .
# .
# .
# .
